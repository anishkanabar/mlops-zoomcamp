# %%
# !python -V
# Out:
# Python 3.8.3

# %%
import pandas as pd

# %%
import pickle

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from sklearn.feature_extraction import DictVectorizer
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.linear_model import Ridge

from sklearn.metrics import mean_squared_error

# %%
import mlflow

mlflow.set_tracking_uri("sqlite:///mlflow.db")
mlflow.set_experiment("nyc-taxi-experiment")
# Out:
# <Experiment: artifact_location='file:///c:/Users/TNEL/Documents/GitHub/mlops-zoomcamp/02-experiment-tracking/mlruns/1', creation_time=1684099241486, experiment_id='1', last_update_time=1684099241486, lifecycle_stage='active', name='nyc-taxi-experiment', tags={}>

# %%
df_fname = 'C:/Users/TNEL/data/green_tripdata_2021-01.parquet'
df = pd.read_parquet(df_fname)

df['duration'] = df.lpep_dropoff_datetime - df.lpep_pickup_datetime
df.duration = df.duration.apply(lambda td: td.total_seconds() / 60)

df = df[(df.duration >= 1) & (df.duration <= 60)]

categorical = ['PULocationID', 'DOLocationID']
numerical = ['trip_distance']

df[categorical] = df[categorical].astype(str)

# %%
train_dicts = df[categorical + numerical].to_dict(orient='records')

dv = DictVectorizer()
X_train = dv.fit_transform(train_dicts)

target = 'duration'
y_train = df[target].values

lr = LinearRegression()
lr.fit(X_train, y_train)

y_pred = lr.predict(X_train)

mean_squared_error(y_train, y_pred, squared=False)
# Out:
# 9.775464289164724

# %%
sns.distplot(y_pred, label='prediction')
sns.distplot(y_train, label='actual')

plt.legend()

# %%
def read_dataframe(filename):
    if filename.endswith('.csv'):
        df = pd.read_csv(filename)

        df.lpep_dropoff_datetime = pd.to_datetime(df.lpep_dropoff_datetime)
        df.lpep_pickup_datetime = pd.to_datetime(df.lpep_pickup_datetime)
    elif filename.endswith('.parquet'):
        df = pd.read_parquet(filename)

    df['duration'] = df.lpep_dropoff_datetime - df.lpep_pickup_datetime
    df.duration = df.duration.apply(lambda td: td.total_seconds() / 60)

    df = df[(df.duration >= 1) & (df.duration <= 60)]

    categorical = ['PULocationID', 'DOLocationID']
    df[categorical] = df[categorical].astype(str)
    
    return df

# %%
df_train = read_dataframe('C:/Users/TNEL/data/green_tripdata_2021-01.parquet')
df_val = read_dataframe('C:/Users/TNEL/data/green_tripdata_2021-02.parquet')

# %%
len(df_train), len(df_val)
# Out:
# (73908, 61921)

# %%
df_train['PU_DO'] = df_train['PULocationID'] + '_' + df_train['DOLocationID']
df_val['PU_DO'] = df_val['PULocationID'] + '_' + df_val['DOLocationID']

# %%
categorical = ['PU_DO'] #'PULocationID', 'DOLocationID']
numerical = ['trip_distance']

dv = DictVectorizer()

train_dicts = df_train[categorical + numerical].to_dict(orient='records')
X_train = dv.fit_transform(train_dicts)

val_dicts = df_val[categorical + numerical].to_dict(orient='records')
X_val = dv.transform(val_dicts)

# %%
target = 'duration'
y_train = df_train[target].values
y_val = df_val[target].values

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)

y_pred = lr.predict(X_val)

mean_squared_error(y_val, y_pred, squared=False)
# Out:
# 7.479582272234666

# %%
with open('models/lin_reg.bin', 'wb') as f_out:
    pickle.dump((dv, lr), f_out)

# %%
with mlflow.start_run():

    mlflow.set_tag("developer", "anish")

    mlflow.log_param("train-data-path", "./data/green_tripdata_2021-01.csv")
    mlflow.log_param("valid-data-path", "./data/green_tripdata_2021-02.csv")

    alpha = 0.1
    mlflow.log_param("alpha", alpha)
    lr = Lasso(alpha)
    lr.fit(X_train, y_train)

    y_pred = lr.predict(X_val)
    rmse = mean_squared_error(y_val, y_pred, squared=False)
    mlflow.log_metric("rmse", rmse)

    mlflow.log_artifact(local_path="models/lin_reg.bin", artifact_path="models_pickle")

# %%
import xgboost as xgb

# %%
from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
from hyperopt.pyll import scope

# %%
train = xgb.DMatrix(X_train, label=y_train)
valid = xgb.DMatrix(X_val, label=y_val)

# %%
def objective(params):
    with mlflow.start_run():
        mlflow.set_tag("model", "xgboost")
        mlflow.log_params(params)
        booster = xgb.train(
            params=params,
            dtrain=train,
            num_boost_round=1000,
            evals=[(valid, 'validation')],
            early_stopping_rounds=50
        )
        y_pred = booster.predict(valid)
        rmse = mean_squared_error(y_val, y_pred, squared=False)
        mlflow.log_metric("rmse", rmse)

    return {'loss': rmse, 'status': STATUS_OK}

# %%
search_space = {
    'max_depth': scope.int(hp.quniform('max_depth', 4, 100, 1)),
    'learning_rate': hp.loguniform('learning_rate', -3, 0),
    'reg_alpha': hp.loguniform('reg_alpha', -5, -1),
    'reg_lambda': hp.loguniform('reg_lambda', -6, -1),
    'min_child_weight': hp.loguniform('min_child_weight', -1, 3),
    'objective': 'reg:linear',
    'seed': 42
}

best_result = fmin(
    fn=objective,
    space=search_space,
    algo=tpe.suggest,
    max_evals=50,
    trials=Trials()
)
# Out:
# [20:35:58] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-07593ffd91cd9da33-1\xgboost\xgboost-ci-windows\src\objective\regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:14.50310
# [1]	validation-rmse:10.71825
# [2]	validation-rmse:8.69450
# [3]	validation-rmse:7.66602
# [4]	validation-rmse:7.15269
# [5]	validation-rmse:6.89372
# [6]	validation-rmse:6.75713
# [7]	validation-rmse:6.67774
# [8]	validation-rmse:6.63414
# [9]	validation-rmse:6.60806
# [10]	validation-rmse:6.59158
# [11]	validation-rmse:6.58195
# [12]	validation-rmse:6.57492
# [13]	validation-rmse:6.56545
# [14]	validation-rmse:6.56074
# [15]	validation-rmse:6.55745
# [16]	validation-rmse:6.55447
# [17]	validation-rmse:6.55048
# [18]	validation-rmse:6.54752
# [19]	validation-rmse:6.54454
# [20]	validation-rmse:6.54126
# [21]	validation-rmse:6.53755
# [22]	validation-rmse:6.53508
# [23]	validation-rmse:6.53062
# [24]	validation-rmse:6.52799
# [25]	validation-rmse:6.52679
# [26]	validation-rmse:6.52533
# [27]	validation-rmse:6.52343
# [28]	validation-rmse:6.52005
# [29]	validation-rmse:6.51711
# [30]	validation-rmse:6.51504
# [31]	validation-rmse:6.51339
# [32]	validation-rmse:6.51088
# [33]	validation-rmse:6.50804
# [34]	validation-rmse:6.50572
# [35]	validation-rmse:6.50366
# [36]	validation-rmse:6.50053
# [37]	validation-rmse:6.49864
# [38]	validation-rmse:6.49681
# [39]	validation-rmse:6.49504
# [40]	validation-rmse:6.49295
# [41]	validation-rmse:6.49159
# [42]	validation-rmse:6.49009
# [43]	validation-rmse:6.48844
# [44]	validation-rmse:6.48665
# [45]	validation-rmse:6.48540
# [46]	validation-rmse:6.48408
# [47]	validation-rmse:6.48211
# [48]	validation-rmse:6.48081
# [49]	validation-rmse:6.47942
# [50]	validation-rmse:6.47732
# [51]	validation-rmse:6.47680
# [52]	validation-rmse:6.47498
# [53]	validation-rmse:6.47055
# [54]	validation-rmse:6.46960
# [55]	validation-rmse:6.46827
# [56]	validation-rmse:6.46715
# [57]	validation-rmse:6.46610
# [58]	validation-rmse:6.46534
# [59]	validation-rmse:6.46479
# [60]	validation-rmse:6.46389
# [61]	validation-rmse:6.46201
# [62]	validation-rmse:6.46126
# [63]	validation-rmse:6.46111
# [64]	validation-rmse:6.45890
# [65]	validation-rmse:6.45742
# [66]	validation-rmse:6.45612
# [67]	validation-rmse:6.45530
# [68]	validation-rmse:6.45428
# [69]	validation-rmse:6.45336
# [70]	validation-rmse:6.45244
# [71]	validation-rmse:6.45123
# [72]	validation-rmse:6.44869
# [73]	validation-rmse:6.44715
# [74]	validation-rmse:6.44604
# [75]	validation-rmse:6.44546
# [76]	validation-rmse:6.44475
# [77]	validation-rmse:6.44319
# [78]	validation-rmse:6.44226
# [79]	validation-rmse:6.44222
# [80]	validation-rmse:6.44143
# [81]	validation-rmse:6.44038
# [82]	validation-rmse:6.43908
# [83]	validation-rmse:6.43700
# [84]	validation-rmse:6.43660
# [85]	validation-rmse:6.43551
# [86]	validation-rmse:6.43497
# [87]	validation-rmse:6.43384
# [88]	validation-rmse:6.43331
# [89]	validation-rmse:6.43297
# [90]	validation-rmse:6.43229
# [91]	validation-rmse:6.43175
# [92]	validation-rmse:6.43124
# [93]	validation-rmse:6.43018
# [94]	validation-rmse:6.42945
# [95]	validation-rmse:6.42866
# [96]	validation-rmse:6.42701
# [97]	validation-rmse:6.42711
# [98]	validation-rmse:6.42617
# [99]	validation-rmse:6.42538
# [100]	validation-rmse:6.42476
# [101]	validation-rmse:6.42372
# [102]	validation-rmse:6.42280
# [103]	validation-rmse:6.42220
# [104]	validation-rmse:6.42195
# [105]	validation-rmse:6.42078
# [106]	validation-rmse:6.42057
# [107]	validation-rmse:6.41969
# [108]	validation-rmse:6.41889
# [109]	validation-rmse:6.41800
# [110]	validation-rmse:6.41713
# [111]	validation-rmse:6.41697
# [112]	validation-rmse:6.41641
# [113]	validation-rmse:6.41620
# [114]	validation-rmse:6.41563
# [115]	validation-rmse:6.41439
# [116]	validation-rmse:6.41315
# [117]	validation-rmse:6.41320
# [118]	validation-rmse:6.41270
# [119]	validation-rmse:6.41188
# [120]	validation-rmse:6.41151
# [121]	validation-rmse:6.41124
# [122]	validation-rmse:6.40969
# [123]	validation-rmse:6.40910
# [124]	validation-rmse:6.40868
# [125]	validation-rmse:6.40849
# [126]	validation-rmse:6.40799
# [127]	validation-rmse:6.40725
# [128]	validation-rmse:6.40685
# [129]	validation-rmse:6.40675
# [130]	validation-rmse:6.40658
# [131]	validation-rmse:6.40658
# [132]	validation-rmse:6.40592
# [133]	validation-rmse:6.40540
# [134]	validation-rmse:6.40510
# [135]	validation-rmse:6.40465
# [136]	validation-rmse:6.40405
# [137]	validation-rmse:6.40333
# [138]	validation-rmse:6.40378
# [139]	validation-rmse:6.40158
# [140]	validation-rmse:6.40099
# [141]	validation-rmse:6.40069
# [142]	validation-rmse:6.40034
# [143]	validation-rmse:6.39998
# [144]	validation-rmse:6.39952
# [145]	validation-rmse:6.39933
# [146]	validation-rmse:6.39906
# [147]	validation-rmse:6.39841
# [148]	validation-rmse:6.39763
# [149]	validation-rmse:6.39752
# [150]	validation-rmse:6.39762
# [151]	validation-rmse:6.39680
# [152]	validation-rmse:6.39632
# [153]	validation-rmse:6.39573
# [154]	validation-rmse:6.39552
# [155]	validation-rmse:6.39399
# [156]	validation-rmse:6.39270
# [157]	validation-rmse:6.39333
# [158]	validation-rmse:6.39279
# [159]	validation-rmse:6.39238
# [160]	validation-rmse:6.39250
# [161]	validation-rmse:6.39226
# [162]	validation-rmse:6.39234
# [163]	validation-rmse:6.39190
# [164]	validation-rmse:6.39133
# [165]	validation-rmse:6.38889
# [166]	validation-rmse:6.38812
# [167]	validation-rmse:6.38781
# [168]	validation-rmse:6.38729
# [169]	validation-rmse:6.38685
# [170]	validation-rmse:6.38628
# [171]	validation-rmse:6.38593
# [172]	validation-rmse:6.38540
# [173]	validation-rmse:6.38435
# [174]	validation-rmse:6.38420
# [175]	validation-rmse:6.38451
# [176]	validation-rmse:6.38388
# [177]	validation-rmse:6.38383
# [178]	validation-rmse:6.38358
# [179]	validation-rmse:6.38298
# [180]	validation-rmse:6.38253
# [181]	validation-rmse:6.38233
# [182]	validation-rmse:6.38311
# [183]	validation-rmse:6.38325
# [184]	validation-rmse:6.38291
# [185]	validation-rmse:6.38270
# [186]	validation-rmse:6.38257
# [187]	validation-rmse:6.38217
# [188]	validation-rmse:6.38197
# [189]	validation-rmse:6.38151
# [190]	validation-rmse:6.38121
# [191]	validation-rmse:6.38014
# [192]	validation-rmse:6.37896
# [193]	validation-rmse:6.37894
# [194]	validation-rmse:6.37897
# [195]	validation-rmse:6.37876
# [196]	validation-rmse:6.37836
# [197]	validation-rmse:6.37842
# [198]	validation-rmse:6.37823
# [199]	validation-rmse:6.37776
# [200]	validation-rmse:6.37761
# [201]	validation-rmse:6.37731
# [202]	validation-rmse:6.37761
# [203]	validation-rmse:6.37728
# [204]	validation-rmse:6.37721
# [205]	validation-rmse:6.37747
# [206]	validation-rmse:6.37709
# [207]	validation-rmse:6.37687
# [208]	validation-rmse:6.37656
# [209]	validation-rmse:6.37631
# [210]	validation-rmse:6.37609
# [211]	validation-rmse:6.37588
# [212]	validation-rmse:6.37573
# [213]	validation-rmse:6.37536
# [214]	validation-rmse:6.37497
# [215]	validation-rmse:6.37487
# [216]	validation-rmse:6.37447
# [217]	validation-rmse:6.37421
# [218]	validation-rmse:6.37408
# [219]	validation-rmse:6.37364
# [220]	validation-rmse:6.37354
# [221]	validation-rmse:6.37342
# [222]	validation-rmse:6.37335
# [223]	validation-rmse:6.37284
# [224]	validation-rmse:6.37234
# [225]	validation-rmse:6.37231
# [226]	validation-rmse:6.37241
# [227]	validation-rmse:6.37205
# [228]	validation-rmse:6.37137
# [229]	validation-rmse:6.37147
# [230]	validation-rmse:6.37092
# [231]	validation-rmse:6.36935
# [232]	validation-rmse:6.36890
# [233]	validation-rmse:6.36808
# [234]	validation-rmse:6.36812
# [235]	validation-rmse:6.36791
# [236]	validation-rmse:6.36801
# [237]	validation-rmse:6.36797
# [238]	validation-rmse:6.36768
# [239]	validation-rmse:6.36771
# [240]	validation-rmse:6.36753
# [241]	validation-rmse:6.36772
# [242]	validation-rmse:6.36757
# [243]	validation-rmse:6.36749
# [244]	validation-rmse:6.36728
# [245]	validation-rmse:6.36716
# [246]	validation-rmse:6.36664
# [247]	validation-rmse:6.36684
# [248]	validation-rmse:6.36574
# [249]	validation-rmse:6.36572
# [250]	validation-rmse:6.36528
# [251]	validation-rmse:6.36500
# [252]	validation-rmse:6.36512
# [253]	validation-rmse:6.36473
# [254]	validation-rmse:6.36355
# [255]	validation-rmse:6.36342
# [256]	validation-rmse:6.36362
# [257]	validation-rmse:6.36330
# [258]	validation-rmse:6.36330
# [259]	validation-rmse:6.36326
# [260]	validation-rmse:6.36238
# [261]	validation-rmse:6.36245
# [262]	validation-rmse:6.36257
# [263]	validation-rmse:6.36231
# [264]	validation-rmse:6.36172
# [265]	validation-rmse:6.36144
# [266]	validation-rmse:6.36151
# [267]	validation-rmse:6.36145
# [268]	validation-rmse:6.36157
# [269]	validation-rmse:6.36153
# [270]	validation-rmse:6.36136
# [271]	validation-rmse:6.36100
# [272]	validation-rmse:6.36031
# [273]	validation-rmse:6.36027
# [274]	validation-rmse:6.36024
# [275]	validation-rmse:6.35999
# [276]	validation-rmse:6.35964
# [277]	validation-rmse:6.35933
# [278]	validation-rmse:6.35887
# [279]	validation-rmse:6.35793
# [280]	validation-rmse:6.35838
# [281]	validation-rmse:6.35826
# [282]	validation-rmse:6.35812
# [283]	validation-rmse:6.35816
# [284]	validation-rmse:6.35811
# [285]	validation-rmse:6.35810
# [286]	validation-rmse:6.35774
# [287]	validation-rmse:6.35760
# [288]	validation-rmse:6.35802
# [289]	validation-rmse:6.35814
# [290]	validation-rmse:6.35808
# [291]	validation-rmse:6.35775
# [292]	validation-rmse:6.35803
# [293]	validation-rmse:6.35674
# [294]	validation-rmse:6.35671
# [295]	validation-rmse:6.35635
# [296]	validation-rmse:6.35617
# [297]	validation-rmse:6.35614
# [298]	validation-rmse:6.35618
# [299]	validation-rmse:6.35606
# [300]	validation-rmse:6.35609
# [301]	validation-rmse:6.35629
# [302]	validation-rmse:6.35620
# [303]	validation-rmse:6.35624
# [304]	validation-rmse:6.35597
# [305]	validation-rmse:6.35580
# [306]	validation-rmse:6.35558
# [307]	validation-rmse:6.35589
# [308]	validation-rmse:6.35567
# [309]	validation-rmse:6.35564
# [310]	validation-rmse:6.35554
# [311]	validation-rmse:6.35559
# [312]	validation-rmse:6.35541
# [313]	validation-rmse:6.35543
# [314]	validation-rmse:6.35534
# [315]	validation-rmse:6.35568
# [316]	validation-rmse:6.35553
# [317]	validation-rmse:6.35564
# [318]	validation-rmse:6.35501
# [319]	validation-rmse:6.35487
# [320]	validation-rmse:6.35472
# [321]	validation-rmse:6.35455
# [322]	validation-rmse:6.35467
# [323]	validation-rmse:6.35459
# [324]	validation-rmse:6.35429
# [325]	validation-rmse:6.35444
# [326]	validation-rmse:6.35452
# [327]	validation-rmse:6.35425
# [328]	validation-rmse:6.35416
# [329]	validation-rmse:6.35376
# [330]	validation-rmse:6.35362
# [331]	validation-rmse:6.35382
# [332]	validation-rmse:6.35405
# [333]	validation-rmse:6.35384
# [334]	validation-rmse:6.35354
# [335]	validation-rmse:6.35367
# [336]	validation-rmse:6.35324
# [337]	validation-rmse:6.35291
# [338]	validation-rmse:6.35275
# [339]	validation-rmse:6.35258
# [340]	validation-rmse:6.35229
# [341]	validation-rmse:6.35230
# [342]	validation-rmse:6.35131
# [343]	validation-rmse:6.35146
# [344]	validation-rmse:6.35175
# [345]	validation-rmse:6.35170
# [346]	validation-rmse:6.35162
# [347]	validation-rmse:6.35310
# [348]	validation-rmse:6.35271
# [349]	validation-rmse:6.35259
# [350]	validation-rmse:6.35250
# [351]	validation-rmse:6.35220
# [352]	validation-rmse:6.35204
# [353]	validation-rmse:6.35233
# [354]	validation-rmse:6.35232
# [355]	validation-rmse:6.35230
# [356]	validation-rmse:6.35165
# [357]	validation-rmse:6.35307
# [358]	validation-rmse:6.35318
# [359]	validation-rmse:6.35316
# [360]	validation-rmse:6.35319
# [361]	validation-rmse:6.35303
# [362]	validation-rmse:6.35315
# [363]	validation-rmse:6.35345
# [364]	validation-rmse:6.35305
# [365]	validation-rmse:6.35309
# [366]	validation-rmse:6.35310
# [367]	validation-rmse:6.35285
# [368]	validation-rmse:6.35289
# [369]	validation-rmse:6.35273
# [370]	validation-rmse:6.35302
# [371]	validation-rmse:6.35306
# [372]	validation-rmse:6.35307
# [373]	validation-rmse:6.35291
# [374]	validation-rmse:6.35305
# [375]	validation-rmse:6.35304
# [376]	validation-rmse:6.35277
# [377]	validation-rmse:6.35196
# [378]	validation-rmse:6.35142
# [379]	validation-rmse:6.35126
# [380]	validation-rmse:6.35115
# [381]	validation-rmse:6.34969
# [382]	validation-rmse:6.35130
# [383]	validation-rmse:6.35131
# [384]	validation-rmse:6.35124
# [385]	validation-rmse:6.35133
# [386]	validation-rmse:6.35122
# [387]	validation-rmse:6.35115
# [388]	validation-rmse:6.35075
# [389]	validation-rmse:6.35080
# [390]	validation-rmse:6.35051
# [391]	validation-rmse:6.35052
# [392]	validation-rmse:6.35033
# [393]	validation-rmse:6.35036
# [394]	validation-rmse:6.35054
# [395]	validation-rmse:6.35096
# [396]	validation-rmse:6.35090
# [397]	validation-rmse:6.35082
# [398]	validation-rmse:6.35071
# [399]	validation-rmse:6.35075
# [400]	validation-rmse:6.35052
# [401]	validation-rmse:6.35065
# [402]	validation-rmse:6.35048
# [403]	validation-rmse:6.35037
# [404]	validation-rmse:6.35033
# [405]	validation-rmse:6.35094
# [406]	validation-rmse:6.35073
# [407]	validation-rmse:6.35088
# [408]	validation-rmse:6.35118
# [409]	validation-rmse:6.35120
# [410]	validation-rmse:6.35104
# [411]	validation-rmse:6.35090
# [412]	validation-rmse:6.35088
# [413]	validation-rmse:6.35099
# [414]	validation-rmse:6.35056
# [415]	validation-rmse:6.35073
# [416]	validation-rmse:6.35071
# [417]	validation-rmse:6.35082
# [418]	validation-rmse:6.35076
# [419]	validation-rmse:6.35077
# [420]	validation-rmse:6.35074
# [421]	validation-rmse:6.35063
# [422]	validation-rmse:6.35060
# [423]	validation-rmse:6.35062
# [424]	validation-rmse:6.35076
# [425]	validation-rmse:6.35096
# [426]	validation-rmse:6.35069
# [427]	validation-rmse:6.35073
# [428]	validation-rmse:6.35097
# [429]	validation-rmse:6.35138
# [430]	validation-rmse:6.35140
# [20:36:36] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-07593ffd91cd9da33-1\xgboost\xgboost-ci-windows\src\objective\regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:15.57386
# [1]	validation-rmse:11.99060
# [2]	validation-rmse:9.78721
# [3]	validation-rmse:8.48164
# [4]	validation-rmse:7.72922
# [5]	validation-rmse:7.29882
# [6]	validation-rmse:7.05291
# [7]	validation-rmse:6.90679
# [8]	validation-rmse:6.81780
# [9]	validation-rmse:6.76025
# [10]	validation-rmse:6.72559
# [11]	validation-rmse:6.70435
# [12]	validation-rmse:6.68853
# [13]	validation-rmse:6.67926
# [14]	validation-rmse:6.67196
# [15]	validation-rmse:6.66183
# [16]	validation-rmse:6.65690
# [17]	validation-rmse:6.65428
# [18]	validation-rmse:6.65075
# [19]	validation-rmse:6.64720
# [20]	validation-rmse:6.64313
# [21]	validation-rmse:6.64045
# [22]	validation-rmse:6.63805
# [23]	validation-rmse:6.63543
# [24]	validation-rmse:6.63351
# [25]	validation-rmse:6.63114
# [26]	validation-rmse:6.62901
# [27]	validation-rmse:6.62724
# [28]	validation-rmse:6.62468
# [29]	validation-rmse:6.62312
# [30]	validation-rmse:6.61844
# [31]	validation-rmse:6.61678
# [32]	validation-rmse:6.61415
# [33]	validation-rmse:6.61146
# [34]	validation-rmse:6.61036
# [35]	validation-rmse:6.60838
# [36]	validation-rmse:6.60623
# [37]	validation-rmse:6.60470
# [38]	validation-rmse:6.60364
# [39]	validation-rmse:6.60141
# [40]	validation-rmse:6.59942
# [41]	validation-rmse:6.59771
# [42]	validation-rmse:6.59662
# [43]	validation-rmse:6.59541
# [44]	validation-rmse:6.59351
# [45]	validation-rmse:6.59227
# [46]	validation-rmse:6.59104
# [47]	validation-rmse:6.59022
# [48]	validation-rmse:6.58828
# [49]	validation-rmse:6.58727
# [50]	validation-rmse:6.58595
# [51]	validation-rmse:6.58510
# [52]	validation-rmse:6.58394
# [53]	validation-rmse:6.58308
# [54]	validation-rmse:6.58161
# [55]	validation-rmse:6.58001
# [56]	validation-rmse:6.57911
# [57]	validation-rmse:6.57832
# [58]	validation-rmse:6.57766
# [59]	validation-rmse:6.57603
# [60]	validation-rmse:6.57564
# [61]	validation-rmse:6.57387
# [62]	validation-rmse:6.57273
# [63]	validation-rmse:6.57183
# [64]	validation-rmse:6.57105
# [65]	validation-rmse:6.56988
# [66]	validation-rmse:6.56809
# [67]	validation-rmse:6.56685
# [68]	validation-rmse:6.56575
# [69]	validation-rmse:6.56462
# [70]	validation-rmse:6.56381
# [71]	validation-rmse:6.56171
# [72]	validation-rmse:6.56018
# [73]	validation-rmse:6.55875
# [74]	validation-rmse:6.55715
# [75]	validation-rmse:6.55694
# [76]	validation-rmse:6.55551
# [77]	validation-rmse:6.55473
# [78]	validation-rmse:6.55400
# [79]	validation-rmse:6.55313
# [80]	validation-rmse:6.55205
# [81]	validation-rmse:6.55125
# [82]	validation-rmse:6.55065
# [83]	validation-rmse:6.54953
# [84]	validation-rmse:6.54887
# [85]	validation-rmse:6.54791
# [86]	validation-rmse:6.54719
# [87]	validation-rmse:6.54646
# [88]	validation-rmse:6.54602
# [89]	validation-rmse:6.54517
# [90]	validation-rmse:6.54416
# [91]	validation-rmse:6.54353
# [92]	validation-rmse:6.54239
# [93]	validation-rmse:6.54172
# [94]	validation-rmse:6.54086
# [95]	validation-rmse:6.53956
# [96]	validation-rmse:6.53856
# [97]	validation-rmse:6.53762
# [98]	validation-rmse:6.53573
# [99]	validation-rmse:6.53471
# [100]	validation-rmse:6.53432
# [101]	validation-rmse:6.53336
# [102]	validation-rmse:6.53237
# [103]	validation-rmse:6.53230
# [104]	validation-rmse:6.53127
# [105]	validation-rmse:6.53003
# [106]	validation-rmse:6.52903
# [107]	validation-rmse:6.52850
# [108]	validation-rmse:6.52789
# [109]	validation-rmse:6.52683
# [110]	validation-rmse:6.52551
# [111]	validation-rmse:6.52491
# [112]	validation-rmse:6.52374
# [113]	validation-rmse:6.52303
# [114]	validation-rmse:6.52163
# [115]	validation-rmse:6.52143
# [116]	validation-rmse:6.52044
# [117]	validation-rmse:6.51961
# [118]	validation-rmse:6.51873
# [119]	validation-rmse:6.51792
# [120]	validation-rmse:6.51750
# [121]	validation-rmse:6.51636
# [122]	validation-rmse:6.51550
# [123]	validation-rmse:6.51473
# [124]	validation-rmse:6.51362
# [125]	validation-rmse:6.51308
# [126]	validation-rmse:6.51239
# [127]	validation-rmse:6.51142
# [128]	validation-rmse:6.51073
# [129]	validation-rmse:6.51014
# [130]	validation-rmse:6.50989
# [131]	validation-rmse:6.50894
# [132]	validation-rmse:6.50808
# [133]	validation-rmse:6.50716
# [134]	validation-rmse:6.50580
# [135]	validation-rmse:6.50496
# [136]	validation-rmse:6.50447
# [137]	validation-rmse:6.50354
# [138]	validation-rmse:6.50175
# [139]	validation-rmse:6.50109
# [140]	validation-rmse:6.50029
# [141]	validation-rmse:6.49868
# [142]	validation-rmse:6.49829
# [143]	validation-rmse:6.49692
# [144]	validation-rmse:6.49666
# [145]	validation-rmse:6.49638
# [146]	validation-rmse:6.49570
# [147]	validation-rmse:6.49495
# [148]	validation-rmse:6.49458
# [149]	validation-rmse:6.49388
# [150]	validation-rmse:6.49374
# [151]	validation-rmse:6.49297
# [152]	validation-rmse:6.49274
# [153]	validation-rmse:6.49231
# [154]	validation-rmse:6.49183
# [155]	validation-rmse:6.49115
# [156]	validation-rmse:6.48995
# [157]	validation-rmse:6.48954
# [158]	validation-rmse:6.48970
# [159]	validation-rmse:6.48916
# [160]	validation-rmse:6.48860
# [161]	validation-rmse:6.48801
# [162]	validation-rmse:6.48754
# [163]	validation-rmse:6.48700
# [164]	validation-rmse:6.48665
# [165]	validation-rmse:6.48625
# [166]	validation-rmse:6.48544
# [167]	validation-rmse:6.48450
# [168]	validation-rmse:6.48369
# [169]	validation-rmse:6.48371
# [170]	validation-rmse:6.48211
# [171]	validation-rmse:6.48159
# [172]	validation-rmse:6.48109
# [173]	validation-rmse:6.48033
# [174]	validation-rmse:6.47979
# [175]	validation-rmse:6.47922
# [176]	validation-rmse:6.47864
# [177]	validation-rmse:6.47781
# [178]	validation-rmse:6.47738
# [179]	validation-rmse:6.47631
# [180]	validation-rmse:6.47578
# [181]	validation-rmse:6.47557
# [182]	validation-rmse:6.47301
# [183]	validation-rmse:6.47269
# [184]	validation-rmse:6.47191
# [185]	validation-rmse:6.47222
# [186]	validation-rmse:6.47199
# [187]	validation-rmse:6.47121
# [188]	validation-rmse:6.47061
# [189]	validation-rmse:6.47050
# [190]	validation-rmse:6.47011
# [191]	validation-rmse:6.46905
# [192]	validation-rmse:6.46866
# [193]	validation-rmse:6.46777
# [194]	validation-rmse:6.46731
# [195]	validation-rmse:6.46694
# [196]	validation-rmse:6.46579
# [197]	validation-rmse:6.46512
# [198]	validation-rmse:6.46501
# [199]	validation-rmse:6.46480
# [200]	validation-rmse:6.46428
# [201]	validation-rmse:6.46429
# [202]	validation-rmse:6.46409
# [203]	validation-rmse:6.46343
# [204]	validation-rmse:6.46317
# [205]	validation-rmse:6.46262
# [206]	validation-rmse:6.46203
# [207]	validation-rmse:6.46135
# [208]	validation-rmse:6.46098
# [209]	validation-rmse:6.46023
# [210]	validation-rmse:6.45979
# [211]	validation-rmse:6.45885
# [212]	validation-rmse:6.45844
# [213]	validation-rmse:6.45826
# [214]	validation-rmse:6.45716
# [215]	validation-rmse:6.45633
# [216]	validation-rmse:6.45601
# [217]	validation-rmse:6.45609
# [218]	validation-rmse:6.45536
# [219]	validation-rmse:6.45520
# [220]	validation-rmse:6.45420
# [221]	validation-rmse:6.45394
# [222]	validation-rmse:6.45373
# [223]	validation-rmse:6.45206
# [224]	validation-rmse:6.45221
# [225]	validation-rmse:6.45181
# [226]	validation-rmse:6.45109
# [227]	validation-rmse:6.45104
# [228]	validation-rmse:6.45051
# [229]	validation-rmse:6.45013
# [230]	validation-rmse:6.44981
# [231]	validation-rmse:6.44939
# [232]	validation-rmse:6.44909
# [233]	validation-rmse:6.44865
# [234]	validation-rmse:6.44801
# [235]	validation-rmse:6.44744
# [236]	validation-rmse:6.44718
# [237]	validation-rmse:6.44696
# [238]	validation-rmse:6.44648
# [239]	validation-rmse:6.44625
# [240]	validation-rmse:6.44589
# [241]	validation-rmse:6.44510
# [242]	validation-rmse:6.44463
# [243]	validation-rmse:6.44421
# [244]	validation-rmse:6.44376
# [245]	validation-rmse:6.44292
# [246]	validation-rmse:6.44252
# [247]	validation-rmse:6.44239
# [248]	validation-rmse:6.44196
# [249]	validation-rmse:6.44277
# [250]	validation-rmse:6.44243
# [251]	validation-rmse:6.44233
# [252]	validation-rmse:6.44207
# [253]	validation-rmse:6.44149
# [254]	validation-rmse:6.44128
# [255]	validation-rmse:6.44106
# [256]	validation-rmse:6.44040
# [257]	validation-rmse:6.44017
# [258]	validation-rmse:6.43972
# [259]	validation-rmse:6.43961
# [260]	validation-rmse:6.43903
# [261]	validation-rmse:6.43869
# [262]	validation-rmse:6.43828
# [263]	validation-rmse:6.43769
# [264]	validation-rmse:6.43703
# [265]	validation-rmse:6.43684
# [266]	validation-rmse:6.43678
# [267]	validation-rmse:6.43639
# [268]	validation-rmse:6.43597
# [269]	validation-rmse:6.43527
# [270]	validation-rmse:6.43480
# [271]	validation-rmse:6.43451
# [272]	validation-rmse:6.43403
# [273]	validation-rmse:6.43375
# [274]	validation-rmse:6.43308
# [275]	validation-rmse:6.43274
# [276]	validation-rmse:6.43237
# [277]	validation-rmse:6.43216
# [278]	validation-rmse:6.43191
# [279]	validation-rmse:6.43142
# [280]	validation-rmse:6.43081
# [281]	validation-rmse:6.43035
# [282]	validation-rmse:6.43020
# [283]	validation-rmse:6.42975
# [284]	validation-rmse:6.42972
# [285]	validation-rmse:6.42956
# [286]	validation-rmse:6.42949
# [287]	validation-rmse:6.42930
# [288]	validation-rmse:6.42918
# [289]	validation-rmse:6.42911
# [290]	validation-rmse:6.42873
# [291]	validation-rmse:6.42842
# [292]	validation-rmse:6.42829
# [293]	validation-rmse:6.42803
# [294]	validation-rmse:6.42747
# [295]	validation-rmse:6.42711
# [296]	validation-rmse:6.42686
# ...
# [516]	validation-rmse:6.37609
# [517]	validation-rmse:6.37614
# [518]	validation-rmse:6.37613
# [519]	validation-rmse:6.37599
# [520]	validation-rmse:6.37593
# [521]	validation-rmse:6.37589
# [522]	validation-rmse:6.37603
# [523]	validation-rmse:6.37610
# [524]	validation-rmse:6.37595
# [525]	validation-rmse:6.37596
# [526]	validation-rmse:6.37569
# [527]	validation-rmse:6.37574
# [528]	validation-rmse:6.37570
# [529]	validation-rmse:6.37564
# [530]	validation-rmse:6.37578
# [531]	validation-rmse:6.37578
# [532]	validation-rmse:6.37580
# [533]	validation-rmse:6.37565
# [534]	validation-rmse:6.37574
# [535]	validation-rmse:6.37565
# [536]	validation-rmse:6.37573
# [537]	validation-rmse:6.37559
# [538]	validation-rmse:6.37558
# [539]	validation-rmse:6.37543
# [540]	validation-rmse:6.37550
# [541]	validation-rmse:6.37542
# [542]	validation-rmse:6.37524
# [543]	validation-rmse:6.37525
# [544]	validation-rmse:6.37495
# [545]	validation-rmse:6.37484
# [546]	validation-rmse:6.37501
# [547]	validation-rmse:6.37499
# [548]	validation-rmse:6.37497
# [549]	validation-rmse:6.37489
# [550]	validation-rmse:6.37485
# [551]	validation-rmse:6.37477
# [552]	validation-rmse:6.37463
# [553]	validation-rmse:6.37452
# [554]	validation-rmse:6.37459
# [555]	validation-rmse:6.37461
# [556]	validation-rmse:6.37476
# [557]	validation-rmse:6.37476
# [558]	validation-rmse:6.37462
# [559]	validation-rmse:6.37457
# [560]	validation-rmse:6.37469
# [561]	validation-rmse:6.37463
# [562]	validation-rmse:6.37446
# [563]	validation-rmse:6.37451
# [564]	validation-rmse:6.37440
# [565]	validation-rmse:6.37433
# [566]	validation-rmse:6.37424
# [567]	validation-rmse:6.37424
# [568]	validation-rmse:6.37423
# [569]	validation-rmse:6.37429
# [570]	validation-rmse:6.37430
# [571]	validation-rmse:6.37440
# [572]	validation-rmse:6.37447
# [573]	validation-rmse:6.37444
# [574]	validation-rmse:6.37445
# [575]	validation-rmse:6.37447
# [576]	validation-rmse:6.37430
# [577]	validation-rmse:6.37437
# [578]	validation-rmse:6.37442
# [579]	validation-rmse:6.37443
# [580]	validation-rmse:6.37421
# [581]	validation-rmse:6.37413
# [582]	validation-rmse:6.37353
# [583]	validation-rmse:6.37345
# [584]	validation-rmse:6.37288
# [585]	validation-rmse:6.37262
# [586]	validation-rmse:6.37275
# [587]	validation-rmse:6.37265
# [588]	validation-rmse:6.37258
# [589]	validation-rmse:6.37259
# [590]	validation-rmse:6.37279
# [591]	validation-rmse:6.37278
# [592]	validation-rmse:6.37224
# [593]	validation-rmse:6.37298
# [594]	validation-rmse:6.37291
# [595]	validation-rmse:6.37290
# [596]	validation-rmse:6.37284
# [597]	validation-rmse:6.37235
# [598]	validation-rmse:6.37239
# [599]	validation-rmse:6.37234
# [600]	validation-rmse:6.37224
# [601]	validation-rmse:6.37219
# [602]	validation-rmse:6.37240
# [603]	validation-rmse:6.37223
# [604]	validation-rmse:6.37208
# [605]	validation-rmse:6.37208
# [606]	validation-rmse:6.37227
# [607]	validation-rmse:6.37228
# [608]	validation-rmse:6.37242
# [609]	validation-rmse:6.37246
# [610]	validation-rmse:6.37242
# [611]	validation-rmse:6.37238
# [612]	validation-rmse:6.37216
# [613]	validation-rmse:6.37209
# [614]	validation-rmse:6.37206
# [615]	validation-rmse:6.37208
# [616]	validation-rmse:6.37201
# [617]	validation-rmse:6.37148
# [618]	validation-rmse:6.37153
# [619]	validation-rmse:6.37152
# [620]	validation-rmse:6.37158
# [621]	validation-rmse:6.37165
# [622]	validation-rmse:6.37218
# [623]	validation-rmse:6.37225
# [624]	validation-rmse:6.37223
# [625]	validation-rmse:6.37225
# [626]	validation-rmse:6.37221
# [627]	validation-rmse:6.37232
# [628]	validation-rmse:6.37343
# [629]	validation-rmse:6.37347
# [630]	validation-rmse:6.37353
# [631]	validation-rmse:6.37339
# [632]	validation-rmse:6.37332
# [633]	validation-rmse:6.37323
# [634]	validation-rmse:6.37320
# [635]	validation-rmse:6.37323
# [636]	validation-rmse:6.37307
# [637]	validation-rmse:6.37314
# [638]	validation-rmse:6.37316
# [639]	validation-rmse:6.37312
# [640]	validation-rmse:6.37308
# [641]	validation-rmse:6.37313
# [642]	validation-rmse:6.37316
# [643]	validation-rmse:6.37322
# [644]	validation-rmse:6.37336
# [645]	validation-rmse:6.37339
# [646]	validation-rmse:6.37335
# [647]	validation-rmse:6.37331
# [648]	validation-rmse:6.37323
# [649]	validation-rmse:6.37308
# [650]	validation-rmse:6.37312
# [651]	validation-rmse:6.37302
# [652]	validation-rmse:6.37299
# [653]	validation-rmse:6.37297
# [654]	validation-rmse:6.37288
# [655]	validation-rmse:6.37288
# [656]	validation-rmse:6.37294
# [657]	validation-rmse:6.37291
# [658]	validation-rmse:6.37291
# [659]	validation-rmse:6.37295
# [660]	validation-rmse:6.37277
# [661]	validation-rmse:6.37273
# [662]	validation-rmse:6.37275
# [663]	validation-rmse:6.37265
# [664]	validation-rmse:6.37256
# [665]	validation-rmse:6.37231
# [666]	validation-rmse:6.37232
# [13:28:21] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-07593ffd91cd9da33-1\xgboost\xgboost-ci-windows\src\objective\regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:14.47846
# [1]	validation-rmse:10.67986
# [2]	validation-rmse:8.63821
# [3]	validation-rmse:7.59744
# [4]	validation-rmse:7.07307
# [5]	validation-rmse:6.80771
# [6]	validation-rmse:6.66629
# [7]	validation-rmse:6.58611
# [8]	validation-rmse:6.53707
# [9]	validation-rmse:6.50445
# [10]	validation-rmse:6.48649
# [11]	validation-rmse:6.47609
# [12]	validation-rmse:6.46667
# [13]	validation-rmse:6.46203
# [14]	validation-rmse:6.45754
# [15]	validation-rmse:6.45216
# [16]	validation-rmse:6.44785
# [17]	validation-rmse:6.44569
# [18]	validation-rmse:6.44116
# [19]	validation-rmse:6.43954
# [20]	validation-rmse:6.43608
# [21]	validation-rmse:6.43452
# [22]	validation-rmse:6.43319
# [23]	validation-rmse:6.43083
# [24]	validation-rmse:6.42933
# [25]	validation-rmse:6.42881
# [26]	validation-rmse:6.42756
# [27]	validation-rmse:6.42545
# [28]	validation-rmse:6.42390
#  74%|███████▍  | 37/50 [16:52:59<1:50:18, 509.11s/trial, best loss: 6.289418461794644]

# %%
mlflow.xgboost.autolog(disable=True)

# %%
with mlflow.start_run():
    
    train = xgb.DMatrix(X_train, label=y_train)
    valid = xgb.DMatrix(X_val, label=y_val)

    best_params = {
        'learning_rate': 0.09585355369315604,
        'max_depth': 30,
        'min_child_weight': 1.060597050922164,
        'objective': 'reg:linear',
        'reg_alpha': 0.018060244040060163,
        'reg_lambda': 0.011658731377413597,
        'seed': 42
    }

    mlflow.log_params(best_params)

    booster = xgb.train(
        params=best_params,
        dtrain=train,
        num_boost_round=1000,
        evals=[(valid, 'validation')],
        early_stopping_rounds=50
    )

    y_pred = booster.predict(valid)
    rmse = mean_squared_error(y_val, y_pred, squared=False)
    mlflow.log_metric("rmse", rmse)

    with open("models/preprocessor.b", "wb") as f_out:
        pickle.dump(dv, f_out)
    mlflow.log_artifact("models/preprocessor.b", artifact_path="preprocessor")

    mlflow.xgboost.log_model(booster, artifact_path="models_mlflow")

# %%
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, ExtraTreesRegressor
from sklearn.svm import LinearSVR

mlflow.sklearn.autolog()

for model_class in (RandomForestRegressor, GradientBoostingRegressor, ExtraTreesRegressor, LinearSVR):

    with mlflow.start_run():

        mlflow.log_param("train-data-path", "./data/green_tripdata_2021-01.csv")
        mlflow.log_param("valid-data-path", "./data/green_tripdata_2021-02.csv")
        mlflow.log_artifact("models/preprocessor.b", artifact_path="preprocessor")

        mlmodel = model_class()
        mlmodel.fit(X_train, y_train)

        y_pred = mlmodel.predict(X_val)
        rmse = mean_squared_error(y_val, y_pred, squared=False)
        mlflow.log_metric("rmse", rmse)
